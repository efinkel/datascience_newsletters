# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from datetime import datetime
import time
import random
from tqdm import tnrange, tqdm_notebook
import numpy as np
import newsletter_crawler as nc
# %reload_ext autoreload
# %autoreload 2

# %%
crawler = nc.newsletter_crawler('data_elixer', 'https://dataelixir.com/issue/?num=', 'https://dataelixir.com/newsletters')

# %%
df = crawler.crawl_archive()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 213/213 [09:58<00:00,  2.81s/it]

# %%
df.to_csv('dataelixir.csv')

# %%
df
# Out:
#      issue_num         date          category_title  \
# 0       Issue1   Sep9th2014                  Notes
# 1       Issue1   Sep9th2014            In the News
# 2       Issue1   Sep9th2014            In the News
# 3       Issue1   Sep9th2014            In the News
# 4       Issue1   Sep9th2014            In the News
# 5       Issue1   Sep9th2014   Tools and Techniques
# 6       Issue1   Sep9th2014   Tools and Techniques
# 7       Issue1   Sep9th2014              Resources
# 8       Issue1   Sep9th2014              Resources
# 9       Issue1   Sep9th2014              Resources
# 10      Issue1   Sep9th2014               Data Viz
# 11      Issue2  Sep17th2014                  Notes
# 12      Issue2  Sep17th2014            In the News
# 13      Issue2  Sep17th2014            In the News
# 14      Issue2  Sep17th2014            In the News
# 15      Issue2  Sep17th2014            In the News
# 16      Issue2  Sep17th2014   Tools and Techniques
# ...
